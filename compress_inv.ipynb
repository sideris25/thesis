# %%
import pygimli as pg
import numpy as np
import matplotlib.pyplot as plt
from pygimli.physics import ert
import pygimli.meshtools as mt
import os
#from matplotlib.path import Path

# %%
data1=pd.read("compressed.npy")

print(data1)
