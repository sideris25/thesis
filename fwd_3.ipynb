# %%
import pygimli as pg
import numpy as np
import matplotlib.pyplot as plt
from pygimli.physics import ert
import pygimli.meshtools as mt

# %%
world=mt.createWorld(start=[-1500,0],end=[2500,-1000],worldMarker=1)

prec = 0.5

 


g0 = mt.createRectangle(start=[0,0], end=[1000,-250], marker=2)
g1_coords = np.round(np.loadtxt('shape_0.txt') / prec) * prec
g1 = mt.createPolygon(g1_coords, marker=3, isClosed=True)

g2_coords = np.round(np.loadtxt('shape_1.txt') / prec) * prec
g2 = mt.createPolygon(g2_coords, marker=4, isClosed=True)

g3_coords = np.round(np.loadtxt('shape_2.txt') / prec) * prec
g3 = mt.createPolygon(g3_coords, marker=5, isClosed=True)


geometry=world+g3+g2+g1

pg.show(geometry,showMesh=True,quality=34)
mesh_cut = mt.createMesh(geometry, quality=34)
x_min,x_max= 0,1000
y_min,y_max= -250,0
ax,_=pg.show(mesh_cut,data=mesh_cut.cellMarkers(), showMesh=False, aspect='auto')    #cellMarkers gia ta xrwmata!
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
# Out:
# (-250.0, 0.0)

# %%
spacing=50
scheme1=ert.createData(
    elecs=np.linspace(start=0,stop=1000,num=len(np.arange(0,1001,spacing)))
    , schemeName='dd'
)
print(scheme1)
# Out:
# 27/12/25 - 20:29:56 - pyGIMLi - INFO - Cache c:\Users\sider\.conda\envs\pg\Lib\site-packages\pygimli\physics\ert\ert.py:createGeometricFactors restored (0.0s x 6): C:\Users\sider\AppData\Roaming\pygimli\Cache\13677005616376912148
# Data: Sensors: 21 data: 171, nonzero entries: ['a', 'b', 'k', 'm', 'n', 'valid']

# %%
for p in scheme1.sensors():
    geometry.createNode(p)
    geometry.createNode(p-[0,0.1]) # φτιάχνω 2 nodes για το FTDT
mesh_fwr=mt.createMesh(geometry,quality=34)
rhomap=[[1,150],
        [3,300],
        [4,50],
        [5,35],
        ] # resistivity για κάθε marker
pg.show(mesh_fwr,data=rhomap,label=pg.unit('res'), cMap='rainbow',logScale=True,aspect='auto')
# Out:
# (<Axes: xlabel='$x$ in m', ylabel='Depth in m'>,
#  <matplotlib.colorbar.Colorbar at 0x24e0c8f64d0>)

# %%
data1=ert.simulate(mesh_fwr,scheme=scheme1, res=rhomap, noiseLevel=5, noiseAbs=1e-6, seed=1337)

pg.info(np.linalg.norm(data1['err']),np.linalg.norm(data1['rhoa']))
pg.info('Simulated data: ',data1)
pg.info('The data contains : ',data1.dataMap().keys())
pg.info('Sim rhoa (min/max) : ' ,min(data1['rhoa']), max(data1['rhoa']))
pg.info('Selected data noise % (min/ma)x : ', min(data1['err'])*100, max(data1['err'])*100)
# Out:
# 27/12/25 - 20:30:29 - pyGIMLi - INFO - Data error estimate (min:max)  0.050002865555083924 : 0.055400121968839554
# 27/12/25 - 20:30:29 - pyGIMLi - INFO - 0.6679803813702146 2019.415601963807
# 27/12/25 - 20:30:29 - pyGIMLi - INFO - Simulated data:  Data: Sensors: 21 data: 171, nonzero entries: ['a', 'b', 'err', 'i', 'k', 'm', 'n', 'r', 'rhoa', 'u', 'valid']
# 27/12/25 - 20:30:29 - pyGIMLi - INFO - The data contains :  ['a', 'b', 'err', 'i', 'ip', 'iperr', 'k', 'm', 'n', 'r', 'rhoa', 'u', 'valid']
# 27/12/25 - 20:30:29 - pyGIMLi - INFO - Sim rhoa (min/max) :  32.766722528087186 361.8440883136941
# 27/12/25 - 20:30:29 - pyGIMLi - INFO - Selected data noise % (min/ma)x :  5.000286555508392 5.540012196883955
# relativeError set to a value > 0.5 .. assuming this is a percentage Error level dividing them by 100

# %%
data1.remove(data1['rhoa']<0)
pg.info('filtered rhoa minmax DD : ', min(data1['rhoa']), max(data1['rhoa']))
#an thelw kanw save
data1.save('fwd_dd.dat')
ert.show(data1,cMap='rainbow',cMin=20,cMax=1000,logScale=True)   #pseudosection
pg.viewer.mpl.showDataContainerAsMatrix(data1,'a','m', 'rhoa',cMap='rainbow',cMin=20,cMax=5000,logScale=True,title='DD')

np.save("abmn_dd.npy", np.column_stack([data1['a'], data1['b'], data1['m'], data1['n']]))
np.save("res_all_dd.npy", np.column_stack([data1['rhoa']]))
abmn_data_dd = np.load("abmn_dd.npy")
print(abmn_data_dd)
print('------------------------------')
res_data_dd =np.load("res_all_dd.npy")
print(res_data_dd)
# Out:
# 27/12/25 - 20:34:15 - pyGIMLi - INFO - filtered rhoa minmax DD :  32.766722528087186 361.8440883136941
# [[ 0  1  2  3]
#  [ 1  2  3  4]
#  [ 2  3  4  5]
#  [ 3  4  5  6]
#  [ 4  5  6  7]
#  [ 5  6  7  8]
#  [ 6  7  8  9]
#  [ 7  8  9 10]
#  [ 8  9 10 11]
#  [ 9 10 11 12]
#  [10 11 12 13]
#  [11 12 13 14]
#  [12 13 14 15]
#  [13 14 15 16]
#  [14 15 16 17]
#  [15 16 17 18]
#  [16 17 18 19]
#  [17 18 19 20]
#  [ 0  1  3  4]
#  [ 1  2  4  5]
#  [ 2  3  5  6]
#  [ 3  4  6  7]
#  [ 4  5  7  8]
#  [ 5  6  8  9]
#  [ 6  7  9 10]
#  [ 7  8 10 11]
#  [ 8  9 11 12]
#  [ 9 10 12 13]
#  [10 11 13 14]
#  [11 12 14 15]
#  [12 13 15 16]
#  [13 14 16 17]
#  [14 15 17 18]
#  [15 16 18 19]
#  [16 17 19 20]
#  [ 0  1  4  5]
#  [ 1  2  5  6]
#  [ 2  3  6  7]
#  [ 3  4  7  8]
#  [ 4  5  8  9]
#  [ 5  6  9 10]
#  [ 6  7 10 11]
#  [ 7  8 11 12]
#  [ 8  9 12 13]
#  [ 9 10 13 14]
#  [10 11 14 15]
#  [11 12 15 16]
#  [12 13 16 17]
#  [13 14 17 18]
#  [14 15 18 19]
#  [15 16 19 20]
#  [ 0  1  5  6]
#  [ 1  2  6  7]
#  [ 2  3  7  8]
#  [ 3  4  8  9]
#  [ 4  5  9 10]
#  [ 5  6 10 11]
#  [ 6  7 11 12]
#  [ 7  8 12 13]
#  [ 8  9 13 14]
#  [ 9 10 14 15]
#  [10 11 15 16]
#  [11 12 16 17]
#  [12 13 17 18]
#  [13 14 18 19]
#  [14 15 19 20]
#  [ 0  1  6  7]
#  [ 1  2  7  8]
#  [ 2  3  8  9]
#  [ 3  4  9 10]
#  [ 4  5 10 11]
#  [ 5  6 11 12]
#  [ 6  7 12 13]
#  [ 7  8 13 14]
#  [ 8  9 14 15]
#  [ 9 10 15 16]
#  [10 11 16 17]
#  [11 12 17 18]
#  [12 13 18 19]
#  [13 14 19 20]
#  [ 0  1  7  8]
#  [ 1  2  8  9]
#  [ 2  3  9 10]
#  [ 3  4 10 11]
#  [ 4  5 11 12]
#  [ 5  6 12 13]
#  [ 6  7 13 14]
#  [ 7  8 14 15]
#  [ 8  9 15 16]
#  [ 9 10 16 17]
#  [10 11 17 18]
#  [11 12 18 19]
#  [12 13 19 20]
#  [ 0  1  8  9]
#  [ 1  2  9 10]
#  [ 2  3 10 11]
#  [ 3  4 11 12]
#  [ 4  5 12 13]
#  [ 5  6 13 14]
#  [ 6  7 14 15]
#  [ 7  8 15 16]
#  [ 8  9 16 17]
#  [ 9 10 17 18]
#  [10 11 18 19]
#  [11 12 19 20]
#  [ 0  1  9 10]
#  [ 1  2 10 11]
#  [ 2  3 11 12]
#  [ 3  4 12 13]
#  [ 4  5 13 14]
#  [ 5  6 14 15]
#  [ 6  7 15 16]
#  [ 7  8 16 17]
#  [ 8  9 17 18]
#  [ 9 10 18 19]
#  [10 11 19 20]
#  [ 0  1 10 11]
#  [ 1  2 11 12]
#  [ 2  3 12 13]
#  [ 3  4 13 14]
#  [ 4  5 14 15]
#  [ 5  6 15 16]
#  [ 6  7 16 17]
#  [ 7  8 17 18]
#  [ 8  9 18 19]
#  [ 9 10 19 20]
#  [ 0  1 11 12]
#  [ 1  2 12 13]
#  [ 2  3 13 14]
#  [ 3  4 14 15]
#  [ 4  5 15 16]
#  [ 5  6 16 17]
#  [ 6  7 17 18]
#  [ 7  8 18 19]
#  [ 8  9 19 20]
#  [ 0  1 12 13]
#  [ 1  2 13 14]
#  [ 2  3 14 15]
#  [ 3  4 15 16]
#  [ 4  5 16 17]
#  [ 5  6 17 18]
#  [ 6  7 18 19]
#  [ 7  8 19 20]
#  [ 0  1 13 14]
#  [ 1  2 14 15]
#  [ 2  3 15 16]
#  [ 3  4 16 17]
#  [ 4  5 17 18]
#  [ 5  6 18 19]
#  [ 6  7 19 20]
#  [ 0  1 14 15]
#  [ 1  2 15 16]
#  [ 2  3 16 17]
#  [ 3  4 17 18]
#  [ 4  5 18 19]
#  [ 5  6 19 20]
#  [ 0  1 15 16]
#  [ 1  2 16 17]
#  [ 2  3 17 18]
#  [ 3  4 18 19]
#  [ 4  5 19 20]
#  [ 0  1 16 17]
#  [ 1  2 17 18]
#  [ 2  3 18 19]
#  [ 3  4 19 20]
#  [ 0  1 17 18]
#  [ 1  2 18 19]
#  [ 2  3 19 20]
#  [ 0  1 18 19]
#  [ 1  2 19 20]
#  [ 0  1 19 20]]
# ------------------------------
# [[317.33432059]
#  [300.55676514]
#  [299.63129923]
#  [278.53346638]
#  [277.07974966]
#  [245.41129526]
#  [191.9480355 ]
#  [115.63131158]
#  [ 81.96316224]
#  [ 52.98923394]
#  [ 45.11299267]
#  [ 43.48933976]
#  [ 74.56586242]
#  [127.5461269 ]
#  [188.96246485]
#  [161.95613556]
#  [124.49726072]
#  [105.46015311]
#  [131.08178185]
#  [170.81486035]
#  [144.81936517]
#  [128.4862267 ]
#  [146.96528284]
#  [152.84548661]
#  [155.59714281]
#  [159.43796635]
#  [177.82968284]
#  [183.57031017]
#  [206.11040856]
#  [205.40337637]]

# %%
# twra ksekinaw na kovw metriseis apo to data gia na ftiaksw ta inversion data
no_mes1= np.array(data1['a']).shape[0]
ix1=np.random.choice(no_mes1, size=int(no_mes1*0.8), replace=False) # mark 8o% twn metrisewn

data1.markInvalid(ix1)
data1.removeInvalid() #ta afairw
pg.viewer.mpl.showDataContainerAsMatrix(data1,'a','m', 'rhoa',cMap='rainbow',cMin=10,cMax=500,logScale=True,title='DD')
# Out:
# (<Axes: xlabel='a', ylabel='m'>,
#  <matplotlib.colorbar.Colorbar at 0x24e1a681050>)

# %%
mgr1=ert.ERTManager('fwd_dd.dat')
mesh1=mgr1.createMesh(quality=34,paraMaxCellSize=40 ,paraDepth=250,paraDx=20)
inv1 = mgr1.invert(mesh=mesh1,verbose=True)
# Check that chi2 is below a reasonable threshold
assert mgr1.inv.chi2() < 6000, f"DD chi2 too high: {mgr1.inv.chi2()}"
# Out:
# 27/12/25 - 21:02:03 - pyGIMLi - INFO - Found 2 regions.
# 27/12/25 - 21:02:03 - pyGIMLi - INFO - Region with smallest marker set to background (marker=1)
# 27/12/25 - 21:02:03 - pyGIMLi - INFO - Found 2 regions.
# 27/12/25 - 21:02:03 - pyGIMLi - INFO - Region with smallest marker set to background (marker=1)
# 27/12/25 - 21:02:03 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 27/12/25 - 21:02:03 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 27/12/25 - 21:02:04 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 31986 Cells: 63508 Boundaries: 47862
# 27/12/25 - 21:02:04 - pyGIMLi - INFO - Use median(data values)=129.144480546599
# 27/12/25 - 21:02:04 - pyGIMLi - INFO - Created startmodel from forward operator:13850, min/max=129.144481/129.144481
# 27/12/25 - 21:02:04 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x0000024E1A03B880>
# Data transformation: Logarithmic LU transform, lower bound 0.0, upper bound 0.0
# Model transformation: Logarithmic transform
# min/max (data): 32.77/362
# min/max (error): 5%/5.54%
# min/max (start model): 129/129
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =  113.86
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =    8.79 (dPhi = 91.07%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    1.56 (dPhi = 68.04%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    1.43 (dPhi = 4.86%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =    1.43 (dPhi = 0.07%) lam: 20.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.07 (< 2.0%)                 #
# ################################################################################

# %%
mgr1.showResultAndFit(vmin=1, vmax=1000, cMap='rainbow', logScale=True,aspect='auto')
meshPD1 = pg.Mesh(mgr1.paraDomain) # Save copy of para mesh for plotting later
pg.show(mgr1.paraDomain, inv1, label=pg.unit('res'), cMap='rainbow', logScale=True, vmin=1, vmax=1000,aspect='auto')
# Out:
# (<Axes: xlabel='$x$ in m', ylabel='Depth in m'>,
#  <matplotlib.colorbar.Colorbar at 0x24e787be4d0>)
