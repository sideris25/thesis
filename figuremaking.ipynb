# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib qt

shapes = []

plt.figure()
plt.xlim(-100, 1100)
plt.ylim(-300, 10)
plt.grid(True)
plt.title("click to draw.")

while True:
    print("Press enter to continue to the next shape")
    
    points=plt.ginput(n=-1, timeout=-1) 
    
    if len(points)==0:

        break

    points_array=np.array(points)
    points_array[:, 0] = np.clip(points_array[:, 0], 0, 1000)   
    points_array[:, 1] = np.clip(points_array[:, 1], -250, 0)  
    prec = 10.0
    points_array = np.round(points_array / prec) * prec
    shapes.append(points_array)

    plt.plot(points_array[:,0], points_array[:,1], '-o')
    plt.draw()
    
    ans = input("enter =new shape , q=quit")
    if ans.lower()=='q':
        break

for i, s in enumerate(shapes):
    filename = f"shape_{i}.txt"
    np.savetxt(filename, s)
    print(f"filesaved as: {filename}")

plt.show()
# Out:
# Press enter to continue to the next shape
# Press enter to continue to the next shape
# Press enter to continue to the next shape
# Press enter to continue to the next shape
# filesaved as: shape_0.txt
# filesaved as: shape_1.txt
# filesaved as: shape_2.txt
# filesaved as: shape_3.txt

# %%
print(shapes)
# Out:
# [array([[   0.        ,    0.        ],
#        [  20.        ,    0.        ],
#        [  81.93548387,    0.        ],
#        [ 174.83870968,    0.        ],
#        [ 221.29032258,    0.        ],
#        [ 314.19354839,    0.        ],
#        [ 378.06451613,    0.        ],
#        [ 441.93548387,    0.        ],
#        [ 511.61290323,    0.        ],
#        [ 594.83870968,    0.        ],
#        [ 728.38709677,    0.        ],
#        [ 871.61290323,    0.        ],
#        [ 980.        ,    0.        ],
#        [1000.        ,    0.        ],
#        [1000.        ,    0.        ],
#        [1000.        ,  -32.60822511],
#        [1000.        ,  -51.3961039 ],
#        [1000.        ,  -52.73809524],
#        [ 906.4516129 ,  -49.38311688],
#        [ 709.03225806,  -51.3961039 ],
#        [ 561.93548387,  -48.04112554],
#        [ 461.29032258,  -44.01515152],
#        [ 271.61290323,  -48.71212121],
#        [  93.5483871 ,  -54.08008658],
#        [   8.38709677,  -54.08008658],
#        [   0.        ,  -51.3961039 ],
#        [   0.        ,  -22.54329004]]), array([[ 561.93548387,  -44.68614719],
#        [ 552.25806452,  -60.79004329],
#        [ 529.03225806,  -81.59090909],
#        [ 494.19354839,  -98.36580087],
#        [ 426.4516129 , -120.50865801],
#        [ 360.64516129, -136.61255411],
#        [ 279.35483871, -158.08441558],
#        [ 192.25806452, -179.55627706],
#        [ 151.61290323, -187.60822511],
#        [  87.74193548, -201.6991342 ],
#        [  35.48387097, -213.10606061],
#        [   0.        , -227.86796537],
#        [   0.        , -247.9978355 ],
#        [   0.        , -250.        ],
#        [   0.        , -250.        ],
#        [  29.67741935, -250.        ],
#        [  91.61290323, -250.        ],
#        [ 149.67741935, -250.        ],
#        [ 223.22580645, -250.        ],
#        [ 263.87096774, -250.        ],
#        [ 329.67741935, -230.55194805],
#        [ 407.09677419, -199.01515152],
#        [ 469.03225806, -174.85930736],
#        [ 544.51612903, -144.66450216],
#        [ 600.64516129, -118.495671  ],
#        [ 670.32258065,  -91.65584416],
#        [ 687.74193548,  -73.53896104],
#        [ 699.35483871,  -59.44805195],
#        [ 710.96774194,  -50.05411255],
#        [ 631.61290323,  -48.71212121]]), array([[   0.64516129,  -52.73809524],
#        [   0.        ,  -86.28787879],
#        [   0.        , -108.43073593],
#        [   0.        , -127.21861472],
#        [   0.        , -156.07142857],
#        [   0.        , -178.88528139],
#        [   0.        , -206.3961039 ],
#        [   0.        , -225.18398268],
#        [   0.        , -229.20995671],
#        [  33.5483871 , -211.76406926],
#        [  83.87096774, -199.68614719],
#        [ 143.87096774, -188.27922078],
#        [ 194.19354839, -179.55627706],
#        [ 271.61290323, -156.74242424],
#        [ 364.51612903, -135.94155844],
#        [ 424.51612903, -118.495671  ],
#        [ 492.25806452,  -97.02380952],
#        [ 527.09677419,  -80.24891775],
#        [ 548.38709677,  -60.11904762],
#        [ 558.06451613,  -44.68614719],
#        [ 455.48387097,  -42.0021645 ],
#        [ 341.29032258,  -46.6991342 ],
#        [ 269.67741935,  -47.37012987],
#        [ 192.25806452,  -52.06709957],
#        [ 130.32258065,  -54.08008658],
#        [  95.48387097,  -54.75108225],
#        [  47.09677419,  -54.75108225]]), array([[ 263.87096774, -249.33982684],
#        [ 265.80645161, -250.        ],
#        [ 321.93548387, -250.        ],
#        [ 561.93548387, -250.        ],
#        [ 732.25806452, -250.        ],
#        [ 881.29032258, -250.        ],
#        [ 997.41935484, -250.        ],
#        [1000.        , -250.        ],
#        [1000.        , -223.17099567],
#        [1000.        , -185.5952381 ],
#        [1000.        , -145.33549784],
#        [1000.        , -104.4047619 ],
#        [1000.        ,  -74.88095238],
#        [1000.        ,  -57.43506494],
#        [ 993.5483871 ,  -52.06709957],
#        [ 958.70967742,  -50.05411255],
#        [ 916.12903226,  -48.71212121],
#        [ 877.41935484,  -48.71212121],
#        [ 840.64516129,  -50.05411255],
#        [ 811.61290323,  -50.05411255],
#        [ 772.90322581,  -52.06709957],
#        [ 740.        ,  -51.3961039 ],
#        [ 716.77419355,  -50.05411255],
#        [ 699.35483871,  -58.77705628],
#        [ 687.74193548,  -73.53896104],
#        [ 668.38709677,  -92.9978355 ],
#        [ 625.80645161, -107.75974026],
#        [ 604.51612903, -116.48268398],
#        [ 558.06451613, -136.61255411],
#        [ 534.83870968, -146.67748918],
#        [ 517.41935484, -154.05844156],
#        [ 496.12903226, -164.12337662],
#        [ 467.09677419, -172.17532468],
#        [ 455.48387097, -183.58225108],
#        [ 426.4516129 , -190.96320346],
#        [ 407.09677419, -199.01515152],
#        [ 380.        , -209.08008658],
#        [ 345.16129032, -224.51298701],
#        [ 327.74193548, -231.22294372],
#        [ 296.77419355, -239.94588745]])]
